# %%
class Chocolate:
    def __init__(self, price: float, adding: str):
        self.price = price
        self.adding = adding
    def show_my_chocolate(self, adding):
        if self.adding!='':
            print('Шоколадный батончик, добавка: '+ self.adding)
        else:
            print('Обычный шоколадный батончик')
    def price_check(self, price):
        if self.price>=0:
            return self.price
        else:
            raise ValueError('Цена ниже 0!')
    def __str__(self):
        if self.price%10 in [0,range(5,10)]:
            return f'Шоколадный батончик, '+ str(self.price)+ ' рублей'
        elif self.price%10 in [2,3,4]:
            return f'Шоколадный батончик, '+ str(self.price)+ ' рубля'
        else:
             return f'Шоколадный батончик, '+ str(self.price)+ ' рубль'

my_mars=Chocolate(20,'карамель')
my_milka=Chocolate(63, '')
my_step=Chocolate(-24, 'фундук')

print(my_mars)
my_mars.show_my_chocolate(Chocolate) #шоколадный батончик, добавка: карамель
my_milka.show_my_chocolate(Chocolate) #обчный шоколадный батончик
my_step.price_check(Chocolate) #ValueError
